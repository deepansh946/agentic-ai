# %% [markdown]
# # Tracing Basics

# %% [markdown]
# ### Setup

# %% [markdown]
# Make sure you set your environment variables, including your OpenAI API key.

# %%
# You can set them inline
import os
os.environ["OPENAI_API_KEY"] = ""
os.environ["LANGSMITH_API_KEY"] = ""
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langsmith-academy"

# %%
# Or you can use a .env file
from dotenv import load_dotenv
load_dotenv(dotenv_path="../../.env", override=True)
# Out:
# True

# %% [markdown]
# ### Tracing with @traceable

# %% [markdown]
# The @traceable decorator is a simple way to log traces from the LangSmith Python SDK. Simply decorate any function with @traceable.
#
# The decorator works by creating a run tree for you each time the function is called and inserting it within the current trace. The function inputs, name, and other information is then streamed to LangSmith. If the function raises an error or if it returns a response, that information is also added to the tree, and updates are patched to LangSmith so you can detect and diagnose sources of errors. This is all done on a background thread to avoid blocking your app's execution.

# %%
# TODO: Import traceable
from openai import OpenAI
from typing import List
import nest_asyncio
from utils import get_vector_db_retriever

MODEL_PROVIDER = "openai"
MODEL_NAME = "gpt-4o-mini"
APP_VERSION = 1.0
RAG_SYSTEM_PROMPT = """You are an assistant for question-answering tasks. 
Use the following pieces of retrieved context to answer the latest question in the conversation. 
If you don't know the answer, just say that you don't know. 
Use three sentences maximum and keep the answer concise.
"""

openai_client = OpenAI()
nest_asyncio.apply()
retriever = get_vector_db_retriever()

# TODO: Set up tracing for each function
def retrieve_documents(question: str):
    return retriever.invoke(question)   # NOTE: This is a LangChain vector db retriever, so this .invoke() call will be traced automatically


def generate_response(question: str, documents):
    formatted_docs = "\n\n".join(doc.page_content for doc in documents)
    messages = [
        {
            "role": "system",
            "content": RAG_SYSTEM_PROMPT
        },
        {
            "role": "user",
            "content": f"Context: {formatted_docs} \n\n Question: {question}"
        }
    ]
    return call_openai(messages)


def call_openai(
    messages: List[dict], model: str = MODEL_NAME, temperature: float = 0.0
) -> str:
    return openai_client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )


def langsmith_rag(question: str):
    documents = retrieve_documents(question)
    response = generate_response(question, documents)
    return response.choices[0].message.content
# Out:
# Fetching pages:   0%|                                                                | 0/197 [00:00<?, ?it/s]Error fetching https://docs.smith.langchain.com/administration/concepts with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/search with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/search with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/concepts with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/search, skipping due to continue_on_failure=True
# Fetching pages:   1%|2                                                       | 1/197 [00:05<17:44,  5.43s/it]Error fetching https://docs.smith.langchain.com/administration/concepts, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/create_account_api_key with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/create_account_api_key with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/create_account_api_key, skipping due to continue_on_failure=True
# Fetching pages:   2%|8                                                       | 3/197 [00:10<11:03,  3.42s/it]Error fetching https://docs.smith.langchain.com/administration/how_to_guides, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/data_purging_compliance with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/manage_organization_by_api with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/manage_organization_by_api with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/data_purging_compliance with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/data_purging_compliance, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/manage_organization_by_api, skipping due to continue_on_failure=True
# Fetching pages:   3%|#4                                                      | 5/197 [00:16<09:48,  3.06s/it]Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_access_control with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_billing with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_access_control with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_billing with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_billing, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_access_control, skipping due to continue_on_failure=True
# Fetching pages:   4%|#9                                                      | 7/197 [00:21<09:14,  2.92s/it]Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_organization with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_resource_tags with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_resource_tags with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_organization with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_resource_tags, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_organization, skipping due to continue_on_failure=True
# Fetching pages:   5%|##5                                                     | 9/197 [00:27<08:54,  2.84s/it]Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_saml_sso with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_scim with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_saml_sso with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_scim with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_scim, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_saml_sso, skipping due to continue_on_failure=True
# Fetching pages:   6%|###                                                    | 11/197 [00:32<08:41,  2.80s/it]Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/update_business_info with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_workspace with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/update_business_info with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_workspace with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/update_business_info, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/administration/how_to_guides/organization_management/set_up_workspace, skipping due to continue_on_failure=True
# Fetching pages:   7%|###6                                                   | 13/197 [00:38<08:30,  2.77s/it]Error fetching https://docs.smith.langchain.com/administration/tutorials/manage_spend with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/tutorials with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/tutorials with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/tutorials/manage_spend with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/administration/tutorials, skipping due to continue_on_failure=True
# Fetching pages:   8%|####1                                                  | 15/197 [00:43<08:21,  2.75s/it]Error fetching https://docs.smith.langchain.com/administration/tutorials/manage_spend, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/concepts with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/concepts with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation, skipping due to continue_on_failure=True
# Fetching pages:   9%|####7                                                  | 17/197 [00:48<08:13,  2.74s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/concepts, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/analyze_single_experiment with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/analyze_single_experiment with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides, skipping due to continue_on_failure=True
# Fetching pages:  10%|#####3                                                 | 19/197 [00:54<08:06,  2.73s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/annotate_traces_inline with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/analyze_single_experiment, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/annotation_queues with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/annotate_traces_inline with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/annotation_queues with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/annotate_traces_inline, skipping due to continue_on_failure=True
# Fetching pages:  11%|#####8                                                 | 21/197 [00:59<07:59,  2.73s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/async with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/annotation_queues, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/attach_user_feedback with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/async with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/attach_user_feedback with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/async, skipping due to continue_on_failure=True
# Fetching pages:  12%|######4                                                | 23/197 [01:05<07:53,  2.72s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/audit_evaluator_scores with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/attach_user_feedback, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/bind_evaluator_to_dataset with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/audit_evaluator_scores with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/bind_evaluator_to_dataset with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/audit_evaluator_scores, skipping due to continue_on_failure=True
# Fetching pages:  13%|######9                                                | 25/197 [01:10<07:47,  2.72s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/compare_experiment_results with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/bind_evaluator_to_dataset, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/create_few_shot_evaluators with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/compare_experiment_results with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/create_few_shot_evaluators with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/compare_experiment_results, skipping due to continue_on_failure=True
# Fetching pages:  14%|#######5                                               | 27/197 [01:16<07:42,  2.72s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/custom_evaluator with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/create_few_shot_evaluators, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/dataset_subset with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/custom_evaluator with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/dataset_subset with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/custom_evaluator, skipping due to continue_on_failure=True
# Fetching pages:  15%|########                                               | 29/197 [01:21<07:36,  2.72s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/dataset_version with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/dataset_subset, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/define_target with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/dataset_version with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/define_target with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/dataset_version, skipping due to continue_on_failure=True
# Fetching pages:  16%|########6                                              | 31/197 [01:26<07:31,  2.72s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/download_experiment_results_as_csv with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/define_target, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_existing_experiment with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/download_experiment_results_as_csv with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_existing_experiment with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/download_experiment_results_as_csv, skipping due to continue_on_failure=True
# Fetching pages:  17%|#########2                                             | 33/197 [01:32<07:25,  2.72s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_llm_application with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_existing_experiment, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_on_intermediate_steps with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_llm_application with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_on_intermediate_steps with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_llm_application, skipping due to continue_on_failure=True
# Fetching pages:  18%|#########7                                             | 35/197 [01:37<07:20,  2.72s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_pairwise with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_on_intermediate_steps, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_with_attachments with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_pairwise with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_with_attachments with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_pairwise, skipping due to continue_on_failure=True
# Fetching pages:  19%|##########3                                            | 37/197 [01:43<07:14,  2.72s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/export_filtered_traces_to_dataset with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/evaluate_with_attachments, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/fetch_perf_metrics_experiment with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/export_filtered_traces_to_dataset with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/fetch_perf_metrics_experiment with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/export_filtered_traces_to_dataset, skipping due to continue_on_failure=True
# Fetching pages:  20%|##########8                                            | 39/197 [01:48<07:09,  2.72s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/filter_experiments_ui with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/fetch_perf_metrics_experiment, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/index_datasets_for_dynamic_few_shot_example_selection with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/filter_experiments_ui with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/index_datasets_for_dynamic_few_shot_example_selection with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/filter_experiments_ui, skipping due to continue_on_failure=True
# Fetching pages:  21%|###########4                                           | 41/197 [01:54<07:03,  2.72s/it]Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/langchain_runnable with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/index_datasets_for_dynamic_few_shot_example_selection, skipping due to continue_on_failure=True
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/langgraph with attempt 1/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/langchain_runnable with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...
# Error fetching https://docs.smith.langchain.com/evaluation/how_to_guides/langgraph with attempt 2/3: Cannot connect to host docs.smith.langchain.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')]. Retrying...

# %% [markdown]
# @traceable handles the RunTree lifecycle for you!

# %%
question = "How can I trace with the @traceable decorator?"
ai_answer = langsmith_rag(question)
print(ai_answer)

# %% [markdown]
# ##### Let's take a look in LangSmith!

# %% [markdown]
# ### Adding Metadata

# %% [markdown]
# LangSmith supports sending arbitrary metadata along with traces.
#
# Metadata is a collection of key-value pairs that can be attached to runs. Metadata can be used to store additional information about a run, such as the version of the application that generated the run, the environment in which the run was generated, or any other information that you want to associate with a run. Similar to tags, you can use metadata to filter runs in the LangSmith UI, and can be used to group runs together for analysis.

# %%
from langsmith import traceable

@traceable(
    # TODO: Add Metadata
    # metadata={"vectordb": "sklearn"}
)
def retrieve_documents(question: str):
    return retriever.invoke(question)

@traceable
def generate_response(question: str, documents):
    formatted_docs = "\n\n".join(doc.page_content for doc in documents)
    messages = [
        {
            "role": "system",
            "content": RAG_SYSTEM_PROMPT
        },
        {
            "role": "user",
            "content": f"Context: {formatted_docs} \n\n Question: {question}"
        }
    ]
    return call_openai(messages)

@traceable(
    # TODO: Add Metadata
    # metadata={"model_name": MODEL_NAME, "model_provider": MODEL_PROVIDER}
)
def call_openai(
    messages: List[dict], model: str = MODEL_NAME, temperature: float = 0.0
) -> str:
    return openai_client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )

@traceable
def langsmith_rag(question: str):
    documents = retrieve_documents(question)
    response = generate_response(question, documents)
    return response.choices[0].message.content

# %%
question = "How do I add Metadata to a Run with @traceable?"
ai_answer = langsmith_rag(question)
print(ai_answer)

# %% [markdown]
# You can also add metadata at runtime!

# %%
question = "How do I add metadata at runtime?"
ai_answer = langsmith_rag(question, langsmith_extra={"metadata": {"runtime_metadata": "foo"}})
print(ai_answer)

# %% [markdown]
# ##### Let's take a look in LangSmith!
